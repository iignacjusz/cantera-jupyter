# %% [markdown]
# # Zmiana folderu

# %%
import os
os.chdir('/home/jovyan/demo/')

# %% [markdown]
# ## Pierwszy przykład

# %%
run demo_shock_point.py
# Out:
# Shock computation for airNASA9noions.cti with composition O2:1 N2:3.76
# Initial State
#    Shock speed 2222.1676663933576 (m/s)
#    Frozen sound Speed 534.1749198060955 (m/s)
#    Shock Mach number 4.16
#    Pressure 770 (Pa)
#    Temperature 728 (K)
#    Density 0.0036701348863386308 (kg/m3)
#    gamma2 (based on frozen sound speed) 1.3600606880747454 (m/s)
#    Specific heat at constant pressure 1089.1548904811086 (J/kg K)
#    viscosity 3.4746495344909265e-05 (kg/m s)
#    viscosity (kinematic)0.009467361941994663 (m2/s)
#    thermal conductivity 0.05463596408945595 (W/m K)
#    thermal diffusivity 0.013668061967750864 (m2/s)
#    Prandtl number 0.6926630830568702
# Frozen shock state
#    Pressure 15621.820929404332 (Pa)
#    Temperature 2679.7746964937646 (K)
#    Density 0.02022814477595808 (kg/m3)
#    Specific heat at constant pressure 1293.4072741396094 (J/kg K)
#    Expansion  ratio 0.1814370485770265 (kg/m3)
#    Entropy 9919.387126898171 (J/kg-K)
# ...

# %%
run demo_ZNDCJ.py
# Out:
# Reaction zone pulse width (exothermic length) = 4.382e-05 m
# Reaction zone induction length = 0.0001444 m
# Reaction zone pulse time (exothermic time) = 8.515e-08 s
# Reaction zone induction time = 3.811e-07 s
